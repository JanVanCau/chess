# %%
import random
import time

# %%
from chess_functions_3 import nieuw_bord, toon_bord
from chess_functions_3 import geldige_zetten_pion, geldige_zetten_paard, geldige_zetten_loper, geldige_zetten_toren, geldige_zetten_koning, geldige_zetten_koningin
from chess_functions_3 import check, checkmate, alle_geldige_zetten, alle_geldige_zetten_score
from chess_functions_3 import random_player, score_player, thinking_one_ahead_player
from chess_functions_3 import doe_zet, spel, N_games

# %%
N_games(random_player, random_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 115.68 seconds.
#
# 333 spelletjes gewonnen door random player.
# 335 spelletjes gewonnen door random player.
#
# 1332 spelletjes onbeslist na 300 zetten.

# %%
N_games(score_player, random_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 89.21 seconds.
#
# 1329 spelletjes gewonnen door score player.
# 4 spelletjes gewonnen door random player.
#
# 667 spelletjes onbeslist na 300 zetten.

# %%
N_games(thinking_one_ahead_player, random_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 549.05 seconds.
#
# 1987 spelletjes gewonnen door thinking 1 ahead player.
# 0 spelletjes gewonnen door random player.
#
# 13 spelletjes onbeslist na 300 zetten.

# %%
N_games(thinking_one_ahead_player, score_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 527.44 seconds.
#
# 1943 spelletjes gewonnen door thinking 1 ahead player.
# 32 spelletjes gewonnen door score player.
#
# 25 spelletjes onbeslist na 300 zetten.

# %%
player_1 = thinking_one_ahead_player('wit', verbose=False)
player_2 = thinking_one_ahead_player('zwart', verbose=False)

spel = game(player_1, player_2, 300)

# %%
spel.play_game()
# Out:
# Zwart wint na 112 zetten.
#
# Game took 1.12 seconds.

# %%
N_games(thinking_one_ahead_player, thinking_one_ahead_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 1682.92 seconds.
#
# 1003 spelletjes gewonnen door thinking 1 ahead player.
# 951 spelletjes gewonnen door thinking 1 ahead player.
#
# 46 spelletjes onbeslist na 300 zetten.

# %%
bord = nieuw_bord()
toon_bord(bord)

# %%
alle_geldige_zetten(bord, 'wit')
# Out:
# [[[6, 0], [5, 0]],
#  [[6, 0], [4, 0]],
#  [[6, 1], [5, 1]],
#  [[6, 1], [4, 1]],
#  [[6, 2], [5, 2]],
#  [[6, 2], [4, 2]],
#  [[6, 3], [5, 3]],
#  [[6, 3], [4, 3]],
#  [[6, 4], [5, 4]],
#  [[6, 4], [4, 4]],
#  [[6, 5], [5, 5]],
#  [[6, 5], [4, 5]],
#  [[6, 6], [5, 6]],
#  [[6, 6], [4, 6]],
#  [[6, 7], [5, 7]],
#  [[6, 7], [4, 7]],
#  [[7, 1], [5, 0]],
#  [[7, 1], [5, 2]],
#  [[7, 6], [5, 5]],
#  [[7, 6], [5, 7]]]
