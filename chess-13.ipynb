# %%
from chess_base_functions_oud import N_games
from chess_players_oud import (
    random_player,
    score_player_2,
    thinking_one_ahead_player,
    thinking_two_ahead_player_conservative,
)

# %%
N_games(thinking_two_ahead_player_conservative, thinking_one_ahead_player, 10, 300)
# Out:
# This took 138.03 seconds.
#
# 10 spelletjes gewonnen door conservative thinking 2 ahead player.
# 0 spelletjes gewonnen door thinking 1 ahead player.
#
# 0 spelletjes onbeslist na 300 zetten.
