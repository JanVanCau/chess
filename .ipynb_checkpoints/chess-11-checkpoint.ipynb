# %%
from chess_base_functions import nieuw_bord, toon_bord, geldige_zetten_pion, geldige_zetten_paard, geldige_zetten_loper, geldige_zetten_toren, geldige_zetten_koning, geldige_zetten_koningin
from chess_base_functions import check, checkmate, alle_geldige_zetten, alle_geldige_zetten_score, doe_zet, spel, N_games

# %%
from chess_players import random_player, score_player, score_player_2, thinking_one_ahead_player, thinking_two_ahead_player_conservative

# %%
N_games(random_player, random_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 124.95 seconds.
#
# 327 spelletjes gewonnen door random player.
# 320 spelletjes gewonnen door random player.
#
# 1353 spelletjes onbeslist na 300 zetten.

# %%
N_games(score_player_2, random_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 102.5 seconds.
#
# 1279 spelletjes gewonnen door score player version 2.
# 5 spelletjes gewonnen door random player.
#
# 716 spelletjes onbeslist na 300 zetten.

# %%
N_games(score_player, random_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 99.26 seconds.
#
# 1331 spelletjes gewonnen door score player.
# 6 spelletjes gewonnen door random player.
#
# 663 spelletjes onbeslist na 300 zetten.

# %%
N_games(score_player_2, score_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 137.5 seconds.
#
# 402 spelletjes gewonnen door score player version 2.
# 124 spelletjes gewonnen door score player.
#
# 1474 spelletjes onbeslist na 300 zetten.

# %%
N_games(score_player, score_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 143.6 seconds.
#
# 281 spelletjes gewonnen door score player.
# 270 spelletjes gewonnen door score player.
#
# 1449 spelletjes onbeslist na 300 zetten.

# %%
N_games(thinking_one_ahead_player, score_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 616.92 seconds.
#
# 1932 spelletjes gewonnen door thinking 1 ahead player.
# 30 spelletjes gewonnen door score player.
#
# 38 spelletjes onbeslist na 300 zetten.

# %%
N_games(thinking_one_ahead_player, score_player_2, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 639.61 seconds.
#
# 1862 spelletjes gewonnen door thinking 1 ahead player.
# 63 spelletjes gewonnen door score player version 2.
#
# 75 spelletjes onbeslist na 300 zetten.

# %%
N_games(thinking_two_ahead_player_conservative, score_player_2, 20, 300)
# Out:
# This took 214.66 seconds.
#
# 20 spelletjes gewonnen door conservative thinking 2 ahead player.
# 0 spelletjes gewonnen door score player version 2.
#
# 0 spelletjes onbeslist na 300 zetten.

# %%
def o(bord):
    bord, wit = tegenstander.make_move(bord)
    toon_bord(bord)
    return bord

def p(bord, van_rij, van_kol, naar_rij, naar_kol):
    bord = doe_zet(bord, 'zwart', [van_rij, van_kol], [naar_rij, naar_kol])
    toon_bord(bord)
    return bord

# %%
tegenstander = thinking_one_ahead_player('wit')

b = nieuw_bord()
toon_bord(b)

# %%
b = o(b)

# %%
b = p(b, 1, 1, 3, 1)

# %%
b = o(b)

# %%
b = p(b, 1, 2, 2, 2)

# %%
b = o(b)

# %%
b = p(b, 0, 3, 2, 1)

# %%
b = o(b)

# %%
b = p(b, 1, 4, 2, 4)

# %%
b = o(b)

# %%
b = p(b, 0, 5, 2, 3)

# %%
b = o(b)

# %%
b = p(b, 0, 6, 2, 5)

# %%
b = o(b)

# %%
b = p(b, 2, 5, 4, 4)

# %%
b = o(b)

# %%
b = p(b, 2, 3, 4, 1)

# %%
b = o(b)

# %%
b = p(b, 2, 1, 3, 0)

# %%
b = o(b)

# %%
b = p(b, 3, 0, 4, 1)

# %%
b = o(b)

# %%
b = p(b, 4, 1, 6, 1)

# %%
b = o(b)

# %%
b = p(b, 6, 1, 7, 0)

# %%
b = o(b)

# %%
b = p(b, 7, 0, 7, 1)

# %%
b = o(b)

# %%
b = p(b, 4, 4, 5, 2)

# %%
b = o(b)

# %%
b = p(b, 5, 2, 6, 0)

# %%
b = o(b)

# %%
b = p(b, 7, 1, 6, 1)

# %%
b = o(b)

# %%
b = p(b, 3, 1, 4, 1)

# %%
b = o(b)

# %%
b = p(b, 6, 1, 6, 2)

# %%
b = o(b)

# %%
b = p(b, 2, 2, 3, 3)

# %%
b = o(b)

# %%
b = p(b, 4, 1, 5, 1)

# %%
b = o(b)

# %%
b = p(b, 6, 2, 7, 2)

# %%
b = o(b)

# %%
b = p(b, 6, 0, 5, 2)

# %%
b = o(b)
# Out:
# wit staat schaakmat.

# %%
tegenstander = thinking_two_ahead_player_conservative('wit')

b = nieuw_bord()
toon_bord(b)

# %%
b = o(b)
