# %%
import random
import time

# %%
from chess_functions_4 import nieuw_bord, toon_bord
from chess_functions_4 import geldige_zetten_pion, geldige_zetten_paard, geldige_zetten_loper, geldige_zetten_toren, geldige_zetten_koning, geldige_zetten_koningin
from chess_functions_4 import check, checkmate, alle_geldige_zetten, alle_geldige_zetten_score
from chess_functions_4 import random_player, score_player, thinking_one_ahead_player
from chess_functions_4 import doe_zet, game, N_games

# %%
player_1 = random_player('wit', verbose=False)
player_2 = random_player('zwart', verbose=False)

spel = game(player_1, player_2, 300)

toon_bord(spel.bord)

# %%
#geldige_zetten_koning(spel, 'wit', 7, 4)

# %%
#alle_geldige_zetten(spel, 'wit')

# %%
#check(spel, 'wit')

# %%
spel.en_passant, spel.castle
# Out:
# ({'wit': [], 'zwart': []},
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': True}})

# %%
doe_zet(spel, 'wit', [7, 1], [5, 0], controle=True)
#spel = doe_zet(spel, 'zwart', [1, 4], [3, 4])

toon_bord(spel.bord)

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': True}})

# %%
doe_zet(spel, 'wit', [6, 3], [5, 3], controle=True)
toon_bord(spel.bord)

# %%
doe_zet(spel, 'wit', [7, 2], [2, 7], controle=True)
toon_bord(spel.bord)

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': True}})

# %%
doe_zet(spel, 'wit', [6, 7], [4, 7], controle=True)
toon_bord(spel.bord)

# %%
spel.en_passant, spel.castle
# Out:
# ([5, 7],
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': True}})

# %%
alle_geldige_zetten(spel, 'zwart')
# Out:
# [[[0, 1], [2, 0]],
#  [[0, 1], [2, 2]],
#  [[0, 6], [2, 5]],
#  [[0, 6], [2, 7]],
#  [[1, 0], [2, 0]],
#  [[1, 0], [3, 0]],
#  [[1, 1], [2, 1]],
#  [[1, 1], [3, 1]],
#  [[1, 2], [2, 2]],
#  [[1, 2], [3, 2]],
#  [[1, 3], [2, 3]],
#  [[1, 3], [3, 3]],
#  [[1, 4], [2, 4]],
#  [[1, 4], [3, 4]],
#  [[1, 5], [2, 5]],
#  [[1, 5], [3, 5]],
#  [[1, 6], [2, 6]],
#  [[1, 6], [3, 6]],
#  [[1, 6], [2, 7]]]

# %%
spel.en_passant, spel.castle
# Out:
# ([5, 7],
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': True}})

# %%
alle_geldige_zetten(spel, 'wit')
# Out:
# [[[2, 7], [3, 6]],
#  [[2, 7], [4, 5]],
#  [[2, 7], [5, 4]],
#  [[2, 7], [6, 3]],
#  [[2, 7], [7, 2]],
#  [[2, 7], [1, 6]],
#  [[4, 7], [3, 7]],
#  [[5, 0], [3, 1]],
#  [[5, 0], [7, 1]],
#  [[5, 0], [4, 2]],
#  [[5, 3], [4, 3]],
#  [[6, 1], [5, 1]],
#  [[6, 1], [4, 1]],
#  [[6, 2], [5, 2]],
#  [[6, 2], [4, 2]],
#  [[6, 4], [5, 4]],
#  [[6, 4], [4, 4]],
#  [[6, 5], [5, 5]],
#  [[6, 5], [4, 5]],
#  [[6, 6], [5, 6]],
#  [[6, 6], [4, 6]],
#  [[7, 0], [7, 1]],
#  [[7, 0], [7, 2]],
#  [[7, 3], [6, 3]],
#  [[7, 3], [7, 2]],
#  [[7, 3], [7, 1]],
#  [[7, 4], [6, 3]],
#  [[7, 6], [5, 5]],
#  [[7, 6], [5, 7]],
#  [[7, 7], [6, 7]],
#  [[7, 7], [5, 7]]]

# %%
spel.en_passant, spel.castle
# Out:
# ([5, 7],
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': True}})

# %%
doe_zet(spel, 'wit', [7, 7], [5, 7], controle=True)
toon_bord(spel.bord)

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': False},
#   'zwart': {'left': True, 'right': True}})

# %%
check(spel, 'wit'), check(spel, 'zwart')
# Out:
# ([], [])

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': False},
#   'zwart': {'left': True, 'right': True}})

# %%
alle_geldige_zetten(spel, 'wit')
# Out:
# [[[2, 7], [3, 6]],
#  [[2, 7], [4, 5]],
#  [[2, 7], [5, 4]],
#  [[2, 7], [6, 3]],
#  [[2, 7], [7, 2]],
#  [[2, 7], [1, 6]],
#  [[4, 7], [3, 7]],
#  [[5, 0], [3, 1]],
#  [[5, 0], [7, 1]],
#  [[5, 0], [4, 2]],
#  [[5, 3], [4, 3]],
#  [[5, 7], [6, 7]],
#  [[5, 7], [7, 7]],
#  [[5, 7], [5, 6]],
#  [[5, 7], [5, 5]],
#  [[5, 7], [5, 4]],
#  [[6, 1], [5, 1]],
#  [[6, 1], [4, 1]],
#  [[6, 2], [5, 2]],
#  [[6, 2], [4, 2]],
#  [[6, 4], [5, 4]],
#  [[6, 4], [4, 4]],
#  [[6, 5], [5, 5]],
#  [[6, 5], [4, 5]],
#  [[6, 6], [5, 6]],
#  [[6, 6], [4, 6]],
#  [[7, 0], [7, 1]],
#  [[7, 0], [7, 2]],
#  [[7, 3], [6, 3]],
#  [[7, 3], [7, 2]],
#  [[7, 3], [7, 1]],
#  [[7, 4], [6, 3]],
#  [[7, 6], [5, 5]]]

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': False},
#   'zwart': {'left': True, 'right': True}})

# %%
alle_geldige_zetten(spel, 'zwart')
# Out:
# [[[0, 1], [2, 0]],
#  [[0, 1], [2, 2]],
#  [[0, 6], [2, 5]],
#  [[0, 6], [2, 7]],
#  [[1, 0], [2, 0]],
#  [[1, 0], [3, 0]],
#  [[1, 1], [2, 1]],
#  [[1, 1], [3, 1]],
#  [[1, 2], [2, 2]],
#  [[1, 2], [3, 2]],
#  [[1, 3], [2, 3]],
#  [[1, 3], [3, 3]],
#  [[1, 4], [2, 4]],
#  [[1, 4], [3, 4]],
#  [[1, 5], [2, 5]],
#  [[1, 5], [3, 5]],
#  [[1, 6], [2, 6]],
#  [[1, 6], [3, 6]],
#  [[1, 6], [2, 7]]]

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': False},
#   'zwart': {'left': True, 'right': True}})

# %%
doe_zet(spel, 'wit', [6, 2], [4, 2], controle=True)
doe_zet(spel, 'wit', [7, 3], [4, 0], controle=True)
toon_bord(spel.bord)

# %%
doe_zet(spel, 'zwart', [1, 4], [3, 4], controle=True)
toon_bord(spel.bord)

# %%
doe_zet(spel, 'zwart', [1, 3], [3, 3], controle=True)
toon_bord(spel.bord)
# Out:
# Ongeldige zet!

# %%
spel.en_passant, spel.castle
# Out:
# ([2, 3],
#  {'wit': {'left': True, 'right': False},
#   'zwart': {'left': True, 'right': True}})

# %%
check(spel, 'wit'), check(spel, 'zwart')
# Out:
# ([], [[4, 0]])

# %%
checkmate(spel, 'wit'), checkmate(spel, 'zwart')
# Out:
# ((False, []),
#  (False,
#   [[[0, 1], [2, 2]],
#    [[0, 1], [1, 3]],
#    [[0, 2], [1, 3]],
#    [[0, 3], [1, 3]],
#    [[0, 4], [1, 4]],
#    [[1, 1], [3, 1]],
#    [[1, 2], [2, 2]]]))

# %%
doe_zet(spel, 'zwart', [0, 4], [1, 4], controle=True)

# %%
toon_bord(spel.bord)

# %%
spel.castle, spel.en_passant
# Out:
# ({'wit': {'left': True, 'right': False},
#   'zwart': {'left': False, 'right': False}},
#  [])

# %%
player_1 = random_player('wit', verbose=False)
player_2 = random_player('zwart', verbose=False)

spel = game(player_1, player_2, 300)

toon_bord(spel.bord)

# %%
doe_zet(spel, 'zwart', [1, 7], [2, 7], controle=True)

# %%
toon_bord(spel.bord)

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': True}})

# %%
doe_zet(spel, 'zwart', [0, 7], [1, 7], controle=True)
toon_bord(spel.bord)

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': False}})

# %%
alle_geldige_zetten(spel, 'zwart')
# Out:
# [[[0, 1], [2, 0]],
#  [[0, 1], [2, 2]],
#  [[0, 6], [2, 5]],
#  [[1, 0], [2, 0]],
#  [[1, 0], [3, 0]],
#  [[1, 1], [2, 1]],
#  [[1, 1], [3, 1]],
#  [[1, 2], [2, 2]],
#  [[1, 2], [3, 2]],
#  [[1, 3], [2, 3]],
#  [[1, 3], [3, 3]],
#  [[1, 4], [2, 4]],
#  [[1, 4], [3, 4]],
#  [[1, 5], [2, 5]],
#  [[1, 5], [3, 5]],
#  [[1, 6], [2, 6]],
#  [[1, 6], [3, 6]],
#  [[1, 7], [0, 7]],
#  [[2, 7], [3, 7]]]

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': False}})

# %%
doe_zet(spel, 'zwart', [0, 1], [2, 0], controle=True)
toon_bord(spel.bord)

# %%
alle_geldige_zetten(spel, 'zwart')
# Out:
# [[[0, 0], [0, 1]],
#  [[0, 6], [2, 5]],
#  [[1, 1], [2, 1]],
#  [[1, 1], [3, 1]],
#  [[1, 2], [2, 2]],
#  [[1, 2], [3, 2]],
#  [[1, 3], [2, 3]],
#  [[1, 3], [3, 3]],
#  [[1, 4], [2, 4]],
#  [[1, 4], [3, 4]],
#  [[1, 5], [2, 5]],
#  [[1, 5], [3, 5]],
#  [[1, 6], [2, 6]],
#  [[1, 6], [3, 6]],
#  [[1, 7], [0, 7]],
#  [[2, 0], [0, 1]],
#  [[2, 0], [4, 1]],
#  [[2, 0], [3, 2]],
#  [[2, 7], [3, 7]]]

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': True, 'right': True},
#   'zwart': {'left': True, 'right': False}})

# %%
player_1 = random_player('wit', verbose=False)
player_2 = random_player('zwart', verbose=False)

spel = game(player_1, player_2, 300)

spel.play_game()
# Out:
# Zwart wint na 488 zetten.
# Speltijd: 0.51 seconden.

# %%
spel.en_passant, spel.castle
# Out:
# ([],
#  {'wit': {'left': False, 'right': False},
#   'zwart': {'left': False, 'right': False}})

# %%
N_games(random_player, random_player, 2000, 300)       # Dit was nog met alle opzoekingen game.bord enz.
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 928.85 seconds.
#
# 318 spelletjes gewonnen door random player.
# 360 spelletjes gewonnen door random player.
#
# 1322 spelletjes onbeslist na 300 zetten.

# %%
N_games(random_player, random_player, 2000, 300)  # Hier met minder game.bord enz. opzoekingen (maar blijkbaar niet veel verschil!)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 918.13 seconds.
#
# 342 spelletjes gewonnen door random player.
# 345 spelletjes gewonnen door random player.
#
# 1313 spelletjes onbeslist na 300 zetten.
