# %%
import random
import time

# %%
from chess_functions_2 import geldige_zetten_pion, geldige_zetten_pion_aanv, geldige_zetten_paard, geldige_zetten_loper
from chess_functions_2 import geldige_zetten_toren, geldige_zetten_koning, geldige_zetten_koningin

# %%
from chess_functions_2 import nieuw_bord, toon_bord, doe_zet_met_controle, doe_zet_zonder_controle, check, checkmate
from chess_functions_2 import alle_geldige_zetten, alle_geldige_zetten_score, spel, N_games, random_player, score_player, thinking_one_ahead_player

# %% [markdown]
# To do:
#
# - en passant + castling + promotie
# - pion die overkant bereikt wordt koningin
# - bestanden overzetten van andere computer **CHECK**
# - functie geldige_pionnen_aanv (schaak- en schaakmatfunctie aanpassen!) **CHECK**
# - functie speel X spelletjes met 2 spelers, elk met hun eigen strategie, die afwisselend met wit en zwart spelen, en kijk wie het vaakst wint **CHECK**
# - nieuwe strategie programmeren **CHECK**:
#   - alle geldige zetten score geven: bijv. pion score 1, paard score 2, toren en loper score 3, koningin score 4, schaak zetten score 5, schaakmat zetten score 6 (maar kan variabel zijn) **CHECK**
#   - zet met hoogste score kiezen **CHECK**
# - deze strategie laten spelen tegen random speler **CHECK**
# - experimenteren met andere scores
# - nieuwe strategie programmeren: 1 zet vooruit denken -> voor elke geldige zet alle tegenzetten oplijsten, voorspellen op basis van score wat andere speler zal doen, dan zet kiezen met hoogste netto-score (rekening houden met: schaakmat -> einde spel) **CHECK**
# - manier bedenken om dit sneller te berekenen: alle tegenzetten oplijsten, en voor elke zet berekenen hoe dit de lijst van tegenzetten beïnvloedt, want voor de meeste stukken zullen de tegenzetten niet opnieuw berekend moeten worden
# - strategie 1 zet vooruit laten spelen tegen score-strategie enz. **CHECK**

# %%
N_games(random_player, random_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 107.92 seconds.
#
# 154 spelletjes gewonnen door random player.
# 164 spelletjes gewonnen door random player.
#
# 1682 spelletjes onbeslist na 300 zetten.

# %%
N_games(score_player, random_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 96.85 seconds.
#
# 872 spelletjes gewonnen door score player.
# 16 spelletjes gewonnen door random player.
#
# 1112 spelletjes onbeslist na 300 zetten.

# %%
N_games(thinking_one_ahead_player, random_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 556.8 seconds.
#
# 1987 spelletjes gewonnen door thinking 1 ahead player.
# 0 spelletjes gewonnen door random player.
#
# 13 spelletjes onbeslist na 300 zetten.

# %%
N_games(thinking_one_ahead_player, score_player, 2000, 300)
# Out:
# 2.5 % done.
# 5.0 % done.
# 7.5 % done.
# 10.0 % done.
# 12.5 % done.
# 15.0 % done.
# 17.5 % done.
# 20.0 % done.
# 22.5 % done.
# 25.0 % done.
# 27.5 % done.
# 30.0 % done.
# 32.5 % done.
# 35.0 % done.
# 37.5 % done.
# 40.0 % done.
# 42.5 % done.
# 45.0 % done.
# 47.5 % done.
# 50.0 % done.
# 52.5 % done.
# 55.0 % done.
# 57.5 % done.
# 60.0 % done.
# 62.5 % done.
# 65.0 % done.
# 67.5 % done.
# 70.0 % done.
# 72.5 % done.
# 75.0 % done.
# 77.5 % done.
# 80.0 % done.
# 82.5 % done.
# 85.0 % done.
# 87.5 % done.
# 90.0 % done.
# 92.5 % done.
# 95.0 % done.
# 97.5 % done.
# 100.0 % done.
#
# This took 516.45 seconds.
#
# 1919 spelletjes gewonnen door thinking 1 ahead player.
# 45 spelletjes gewonnen door score player.
#
# 36 spelletjes onbeslist na 300 zetten.

# %%
bord = nieuw_bord()
wit = thinking_one_ahead_player('wit')

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [1, 4], [2, 4])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 5], [4, 1])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 1], [3, 2])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 4], [1, 4])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [1, 4], [0, 4])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 3], [4, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 6], [2, 5])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [2, 5], [4, 6])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord) #Klopt niet dat wit dit doet, als wit 1 zet vooruitdenkt.

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 7], [4, 6])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 6], [4, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [1, 7], [3, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 4], [0,5])
toon_bord(bord) #Zou ongeldige zet moeten zijn!

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 5], [0,4])
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 7], [1, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [1, 7], [2, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [2, 7], [2, 6])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord) # Zie eerder, onlogische move want verliest zo meteen loper

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 0], [0, 1])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord) # En opnieuw!

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 7], [3, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [1, 1], [2, 1])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [3, 2], [4, 1])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 2], [1, 1])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [3, 7], [3, 6])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [3, 6], [6, 6])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [6, 6], [6, 5])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [2, 6], [2, 5])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [2, 5], [5, 5])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [6, 5], [7, 4])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [5, 5], [7, 5])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord) # Vreemde move, want verliest zo paard?

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 1], [5, 0])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [7, 4], [7, 3])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [7, 5], [6, 5])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 1], [0, 2])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [6, 5], [4, 5])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 5], [4, 4])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [1, 3], [3, 3])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [2, 4], [3, 3])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [5, 0], [6, 1])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 4], [4, 3])
toon_bord(bord) # Schaak tegen opgelost door de ander zelf schaak te zetten! Kan niet!

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [0, 4], [1, 3])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [1, 3], [0, 2])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 3], [4, 1])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 1], [3, 1])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [3, 1], [5, 1])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [2, 1], [3, 0])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [5, 1], [5, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [5, 7], [2, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [3, 3], [4, 3])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [1, 1], [3, 3])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [4, 3], [5, 3])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [2, 7], [5, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [6, 1], [5, 2])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [5, 7], [6, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [6, 7], [5, 7])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)

# %%
bord = doe_zet_met_controle(bord, 'zwart', [, ], [, ])
toon_bord(bord)

# %%
bord, status = wit.make_move(bord)
toon_bord(bord)
