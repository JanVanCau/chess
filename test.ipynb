# %%
list = [[1, 3], [5, 3], [10, 2], [61, 2], [3, 1]]

# %%
m = max([item[1] for item in list])

# %%
m
# Out:
# 3

# %%
proc_list = [item for item in list if item[1] == m]
proc_list
# Out:
# [[1, 3], [5, 3]]
