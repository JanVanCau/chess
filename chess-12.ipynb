# %%
from chess_base_functions import nieuw_bord, toon_bord, doe_zet, N_games
from chess_players import (
    random_player,
    score_player,
    thinking_one_ahead_player,
    thinking_two_ahead_player_conservative,
)

# %%
N_games(thinking_one_ahead_player, score_player, 200, 300)
# Out:
# 0.5 % done.
# 1.0 % done.
# 1.5 % done.
# 2.0 % done.
# 2.5 % done.
# 3.0 % done.
# 3.5 % done.
# 4.0 % done.
# 4.5 % done.
# 5.0 % done.
# 5.5 % done.
# 6.0 % done.
# 6.5 % done.
# 7.0 % done.
# 7.5 % done.
# 8.0 % done.
# 8.5 % done.
# 9.0 % done.
# 9.5 % done.
# 10.0 % done.
# 10.5 % done.
# 11.0 % done.
# 11.5 % done.
# 12.0 % done.
# 12.5 % done.
# 13.0 % done.
# 13.5 % done.
# 14.0 % done.
# 14.5 % done.
# 15.0 % done.
# 15.5 % done.
# 16.0 % done.
# 16.5 % done.
# 17.0 % done.
# 17.5 % done.
# 18.0 % done.
# 18.5 % done.
# 19.0 % done.
# 19.5 % done.
# 20.0 % done.
# 20.5 % done.
# 21.0 % done.
# 21.5 % done.
# 22.0 % done.
# 22.5 % done.
# 23.0 % done.
# 23.5 % done.
# 24.0 % done.
# 24.5 % done.
# 25.0 % done.
# 25.5 % done.
# 26.0 % done.
# 26.5 % done.
# 27.0 % done.
# 27.5 % done.
# 28.0 % done.
# 28.5 % done.
# 29.0 % done.
# 29.5 % done.
# 30.0 % done.
# 30.5 % done.
# 31.0 % done.
# 31.5 % done.
# 32.0 % done.
# 32.5 % done.
# 33.0 % done.
# 33.5 % done.
# ...

# %%
N_games(thinking_two_ahead_player_conservative, score_player_2, 200, 300)
# Out:
# 0.5 % done.
# 1.0 % done.
# 1.5 % done.
# 2.0 % done.
# 2.5 % done.
# 3.0 % done.
# 3.5 % done.
# 4.0 % done.
# 4.5 % done.
# 5.0 % done.
# 5.5 % done.
# 6.0 % done.
# 6.5 % done.
# 7.0 % done.
# 7.5 % done.
# 8.0 % done.
# 8.5 % done.
# 9.0 % done.
# 9.5 % done.
# 10.0 % done.
# 10.5 % done.
# 11.0 % done.
# 11.5 % done.
# 12.0 % done.
# 12.5 % done.
# 13.0 % done.
# 13.5 % done.
# 14.0 % done.
# 14.5 % done.
# 15.0 % done.
# 15.5 % done.
# 16.0 % done.
# 16.5 % done.
# 17.0 % done.
# 17.5 % done.
# 18.0 % done.
# 18.5 % done.
# 19.0 % done.
# 19.5 % done.
# 20.0 % done.
# 20.5 % done.
# 21.0 % done.
# 21.5 % done.
# 22.0 % done.
# 22.5 % done.
# 23.0 % done.
# 23.5 % done.
# 24.0 % done.
# 24.5 % done.
# 25.0 % done.
# 25.5 % done.
# 26.0 % done.
# 26.5 % done.
# 27.0 % done.
# 27.5 % done.
# 28.0 % done.
# 28.5 % done.
# 29.0 % done.
# 29.5 % done.
# 30.0 % done.
# 30.5 % done.
# 31.0 % done.
# 31.5 % done.
# 32.0 % done.
# 32.5 % done.
# 33.0 % done.
# 33.5 % done.
# ...

# %%
N_games(thinking_two_ahead_player_conservative, thinking_one_ahead_player, 200, 300)
# Out:
# 0.5 % done.
# 1.0 % done.
# 1.5 % done.
# 2.0 % done.
# 2.5 % done.
# 3.0 % done.
# 3.5 % done.
# 4.0 % done.
# 4.5 % done.
# 5.0 % done.
# 5.5 % done.
# 6.0 % done.
# 6.5 % done.
# 7.0 % done.
# 7.5 % done.
# 8.0 % done.
# 8.5 % done.
# 9.0 % done.
# 9.5 % done.
# 10.0 % done.
# 10.5 % done.
# 11.0 % done.
# 11.5 % done.
# 12.0 % done.
# 12.5 % done.
# 13.0 % done.
# 13.5 % done.
# 14.0 % done.
# 14.5 % done.
# 15.0 % done.
# 15.5 % done.
# 16.0 % done.
# 16.5 % done.
# 17.0 % done.
# 17.5 % done.
# 18.0 % done.
# 18.5 % done.
# 19.0 % done.
# 19.5 % done.
# 20.0 % done.
# 20.5 % done.
# 21.0 % done.
# 21.5 % done.
# 22.0 % done.
# 22.5 % done.
# 23.0 % done.
# 23.5 % done.
# 24.0 % done.
# 24.5 % done.
# 25.0 % done.
# 25.5 % done.
# 26.0 % done.
# 26.5 % done.
# 27.0 % done.
# 27.5 % done.
# 28.0 % done.
# 28.5 % done.
# 29.0 % done.
# 29.5 % done.
# 30.0 % done.
# 30.5 % done.
# 31.0 % done.
# 31.5 % done.
# 32.0 % done.
# 32.5 % done.
# 33.0 % done.
# 33.5 % done.
# ...
